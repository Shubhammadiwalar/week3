# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = r"C:\Users\shubh\OneDrive\Desktop\intern\week 3\day 2\car_price_prediction.csv"
df = pd.read_csv(file_path)

print("First 5 Rows:")
display(df.head())

print("\nDataset Shape:", df.shape)

print("\nData Types:")
display(df.dtypes)

print("\nSummary Statistics:")
display(df.describe(include='all'))

print("\nMissing Values:")
display(df.isnull().sum())

df = df.drop_duplicates()

num_cols = df.select_dtypes(include=np.number).columns
for col in num_cols:
    df[col].fillna(df[col].median(), inplace=True)

cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    df[col].fillna(df[col].mode()[0] if not df[col].mode().empty else "Unknown", inplace=True)

df.columns = df.columns.str.strip()

for col in cat_cols:
    df[col] = df[col].astype(str).str.strip()

print("\nAfter Cleaning - Missing Values:")
display(df.isnull().sum())

print("\nFinal Dataset Shape:", df.shape)

if len(num_cols) > 0:
    plt.figure()
    df[num_cols[0]].hist()
    plt.title(f"Distribution of {num_cols[0]}")
    plt.xlabel(num_cols[0])
    plt.ylabel("Frequency")
    plt.show()

print("\nEDA and Data Cleaning Completed Successfully.")
# Out:
# First 5 Rows:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4
# Dataset Shape: (19237, 18)
#
# Data Types:
# ID                    int64
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object
# Summary Statistics:
#                   ID         Price   Levy Manufacturer  Model    Prod. year  \
# count   1.923700e+04  1.923700e+04  19237        19237  19237  19237.000000
# unique           NaN           NaN    559           65   1590           NaN
# top              NaN           NaN      -      HYUNDAI  Prius           NaN
# freq             NaN           NaN   5819         3769   1083           NaN
# mean    4.557654e+07  1.855593e+04    NaN          NaN    NaN   2010.912824
# std     9.365914e+05  1.905813e+05    NaN          NaN    NaN      5.668673
# min     2.074688e+07  1.000000e+00    NaN          NaN    NaN   1939.000000
# 25%     4.569837e+07  5.331000e+03    NaN          NaN    NaN   2009.000000
# 50%     4.577231e+07  1.317200e+04    NaN          NaN    NaN   2012.000000
# 75%     4.580204e+07  2.207500e+04    NaN          NaN    NaN   2015.000000
# max     4.581665e+07  2.630750e+07    NaN          NaN    NaN   2020.000000
#
#        Category Leather interior Fuel type Engine volume Mileage  \
# count     19237            19237     19237         19237   19237
# unique       11                2         7           107    7687
# top       Sedan              Yes    Petrol             2    0 km
# freq       8736            13954     10150          3916     721
# mean        NaN              NaN       NaN           NaN     NaN
# std         NaN              NaN       NaN           NaN     NaN
# min         NaN              NaN       NaN           NaN     NaN
# 25%         NaN              NaN       NaN           NaN     NaN
# 50%         NaN              NaN       NaN           NaN     NaN
# 75%         NaN              NaN       NaN           NaN     NaN
# max         NaN              NaN       NaN           NaN     NaN
#
#            Cylinders Gear box type Drive wheels   Doors       Wheel  Color  \
# count   19237.000000         19237        19237   19237       19237  19237
# unique           NaN             4            3       3           2     16
# top              NaN     Automatic        Front  04-May  Left wheel  Black
# freq             NaN         13514        12874   18332       17753   5033
# mean        4.582991           NaN          NaN     NaN         NaN    NaN
# std         1.199933           NaN          NaN     NaN         NaN    NaN
# min         1.000000           NaN          NaN     NaN         NaN    NaN
# 25%         4.000000           NaN          NaN     NaN         NaN    NaN
# 50%         4.000000           NaN          NaN     NaN         NaN    NaN
# 75%         4.000000           NaN          NaN     NaN         NaN    NaN
# max        16.000000           NaN          NaN     NaN         NaN    NaN
#
#              Airbags
# count   19237.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        6.582627
# std         4.320168
# min         0.000000
# 25%         4.000000
# 50%         6.000000
# 75%        12.000000
# max        16.000000
# Missing Values:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64
# After Cleaning - Missing Values:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_20348\285529686.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_20348\285529686.py:30: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0] if not df[col].mode().empty else "Unknown", inplace=True)
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64
# Final Dataset Shape: (18924, 18)
# EDA and Data Cleaning Completed Successfully.
